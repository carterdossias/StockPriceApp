# %% [markdown]
# ## GETTING DATA

# %%
import yfinance as yf
import mysql.connector
import pandas as pd
import numpy as np

def safe_float(value):
    """Convert a value to float if not NaN, otherwise return None."""
    if pd.isnull(value):
        return None
    return float(value)

def main():
    # Database connection parameters
    server = '192.168.0.17'
    username = 'carterdossias'
    password = 'dossias1'
    database = 'Stocks_DB'
    
    # Establish connection to MySQL
    conn = mysql.connector.connect(
        host=server,
        user=username,
        password=password,
        database=database
    )
    cursor = conn.cursor()
    
    # Define the ticker symbol
    ticker_symbol = 'NVDA'
    
    # Fetch historical stock data using yfinance
    tsla = yf.Ticker(ticker_symbol)
    hist = tsla.history(period="max")
    
    # Localize the index to UTC to bypass DST-related issues
    if hist.index.tzinfo is None:
        hist.index = hist.index.tz_localize('UTC', nonexistent='shift_forward', ambiguous='NaT')
    else:
        hist.index = hist.index.tz_convert('UTC')
    
    # Create table name based on ticker symbol (e.g., tsla_data)
    table_name = f"{ticker_symbol}_data"
    
    # SQL to create table if it doesn't exist
    create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {table_name} (
        date DATE PRIMARY KEY,
        open FLOAT,
        high FLOAT,
        low FLOAT,
        close FLOAT,
        volume BIGINT,
        dividends FLOAT,
        splits FLOAT
    )
    """
    cursor.execute(create_table_query)
    conn.commit()
    
    # SQL to insert data into the table with upsert functionality
    insert_query = f"""
    INSERT INTO {table_name} (date, open, high, low, close, volume, dividends, splits)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
    ON DUPLICATE KEY UPDATE
        open = VALUES(open),
        high = VALUES(high),
        low = VALUES(low),
        close = VALUES(close),
        volume = VALUES(volume),
        dividends = VALUES(dividends),
        splits = VALUES(splits)
    """
    
    # Iterate over DataFrame rows and insert into the table
    for index, row in hist.iterrows():
        data_tuple = (
            index.date(), 
            safe_float(row.get('Open')), 
            safe_float(row.get('High')), 
            safe_float(row.get('Low')), 
            safe_float(row.get('Close')), 
            int(row.get('Volume')) if not pd.isnull(row.get('Volume')) else None, 
            safe_float(row.get('Dividends')), 
            safe_float(row.get('Stock Splits'))
        )
        cursor.execute(insert_query, data_tuple)
    
    # Commit changes and close the connection
    conn.commit()
    cursor.close()
    conn.close()
    print("Data imported successfully into the MySQL database.")

if __name__ == "__main__":
    main()
# Out:
# Data imported successfully into the MySQL database.

# %% [markdown]
# ## GETTING NEWS WITH FINNHUB API

# %%
import requests
import datetime
import time
import pandas as pd

# Finnhub API key and endpoint details
API_KEY = "cv6gs71r01qi7f6qb7kgcv6gs71r01qi7f6qb7l0"
BASE_URL = "https://finnhub.io/api/v1/company-news"
symbol = "NVDA"

# Define the start date (adjust as needed) and end date (today)
start_date = datetime.date(2020, 1, 1)  # Example start date
end_date = datetime.date.today()

all_news = []
current_start = start_date

# Maximum number of retries for a 429 error
MAX_RETRIES = 5

while current_start <= end_date:
    # Define a weekly window: from current_start to current_start + 6 days
    current_end = current_start + datetime.timedelta(days=6)
    if current_end > end_date:
        current_end = end_date

    # Format the dates as YYYY-MM-DD strings
    params = {
        "symbol": symbol,
        "from": current_start.strftime("%Y-%m-%d"),
        "to": current_end.strftime("%Y-%m-%d"),
        "token": API_KEY
    }
    
    print(f"Fetching news for {params['from']} to {params['to']}")
    
    retries = 0
    success = False
    while not success and retries < MAX_RETRIES:
        response = requests.get(BASE_URL, params=params)
        if response.status_code == 200:
            news_items = response.json()
            if news_items:
                all_news.extend(news_items)
            success = True
        elif response.status_code == 429:
            # Rate limit error: wait longer and then retry
            retries += 1
            wait_time = 2 ** retries  # exponential backoff
            print(f"Rate limit reached. Retrying in {wait_time} seconds (attempt {retries}/{MAX_RETRIES})")
            time.sleep(wait_time)
        else:
            print(f"Error: {response.status_code} for range {params['from']} to {params['to']}")
            success = True  # exit retry loop on non-429 errors

    # Move to the next week
    current_start = current_end + datetime.timedelta(days=1)
    # Sleep briefly to help avoid rapid-fire requests
    time.sleep(1)

# Convert the collected news data to a DataFrame
df = pd.DataFrame(all_news)

# Helper function to safely convert Unix timestamp to "YYYY-MM-DD"
def safe_convert(ts):
    try:
        ts_val = int(ts)
        if ts_val <= 0:
            return ""
        return datetime.datetime.fromtimestamp(ts_val).strftime("%Y-%m-%d")
    except Exception as e:
        return ""

# If the 'datetime' column exists, convert the Unix timestamp to "YYYY-MM-DD"
if not df.empty and 'datetime' in df.columns:
    df['datetime'] = df['datetime'].apply(safe_convert)

csv_filename = "NVDA_all_news_weekly.csv"
df.to_csv(csv_filename, index=False)
print(f"All news data saved to {csv_filename}")
# Out:
# Fetching news for 2020-01-01 to 2020-01-07
# Fetching news for 2020-01-08 to 2020-01-14
# Fetching news for 2020-01-15 to 2020-01-21
# Fetching news for 2020-01-22 to 2020-01-28
# Fetching news for 2020-01-29 to 2020-02-04
# Fetching news for 2020-02-05 to 2020-02-11
# Fetching news for 2020-02-12 to 2020-02-18
# Fetching news for 2020-02-19 to 2020-02-25
# Fetching news for 2020-02-26 to 2020-03-03
# Fetching news for 2020-03-04 to 2020-03-10
# Fetching news for 2020-03-11 to 2020-03-17
# Fetching news for 2020-03-18 to 2020-03-24
# Fetching news for 2020-03-25 to 2020-03-31
# Fetching news for 2020-04-01 to 2020-04-07
# Fetching news for 2020-04-08 to 2020-04-14
# Fetching news for 2020-04-15 to 2020-04-21
# Fetching news for 2020-04-22 to 2020-04-28
# Fetching news for 2020-04-29 to 2020-05-05
# Fetching news for 2020-05-06 to 2020-05-12
# Fetching news for 2020-05-13 to 2020-05-19
# Fetching news for 2020-05-20 to 2020-05-26
# Fetching news for 2020-05-27 to 2020-06-02
# Fetching news for 2020-06-03 to 2020-06-09
# Fetching news for 2020-06-10 to 2020-06-16
# Fetching news for 2020-06-17 to 2020-06-23
# Fetching news for 2020-06-24 to 2020-06-30
# Fetching news for 2020-07-01 to 2020-07-07
# Fetching news for 2020-07-08 to 2020-07-14
# Fetching news for 2020-07-15 to 2020-07-21
# Fetching news for 2020-07-22 to 2020-07-28
# Fetching news for 2020-07-29 to 2020-08-04
# Fetching news for 2020-08-05 to 2020-08-11
# Fetching news for 2020-08-12 to 2020-08-18
# Fetching news for 2020-08-19 to 2020-08-25
# Fetching news for 2020-08-26 to 2020-09-01
# Fetching news for 2020-09-02 to 2020-09-08
# Fetching news for 2020-09-09 to 2020-09-15
# Fetching news for 2020-09-16 to 2020-09-22
# Fetching news for 2020-09-23 to 2020-09-29
# Fetching news for 2020-09-30 to 2020-10-06
# Fetching news for 2020-10-07 to 2020-10-13
# Fetching news for 2020-10-14 to 2020-10-20
# Fetching news for 2020-10-21 to 2020-10-27
# Fetching news for 2020-10-28 to 2020-11-03
# Fetching news for 2020-11-04 to 2020-11-10
# Fetching news for 2020-11-11 to 2020-11-17
# Fetching news for 2020-11-18 to 2020-11-24
# Fetching news for 2020-11-25 to 2020-12-01
# Fetching news for 2020-12-02 to 2020-12-08
# Fetching news for 2020-12-09 to 2020-12-15
# Fetching news for 2020-12-16 to 2020-12-22
# Fetching news for 2020-12-23 to 2020-12-29
# Fetching news for 2020-12-30 to 2021-01-05
# Fetching news for 2021-01-06 to 2021-01-12
# Fetching news for 2021-01-13 to 2021-01-19
# Fetching news for 2021-01-20 to 2021-01-26
# Fetching news for 2021-01-27 to 2021-02-02
# Fetching news for 2021-02-03 to 2021-02-09
# Fetching news for 2021-02-10 to 2021-02-16
# Fetching news for 2021-02-17 to 2021-02-23
# Fetching news for 2021-02-24 to 2021-03-02
# Fetching news for 2021-03-03 to 2021-03-09
# Fetching news for 2021-03-10 to 2021-03-16
# Fetching news for 2021-03-17 to 2021-03-23
# Fetching news for 2021-03-24 to 2021-03-30
# Fetching news for 2021-03-31 to 2021-04-06
# Fetching news for 2021-04-07 to 2021-04-13
# Fetching news for 2021-04-14 to 2021-04-20
# Fetching news for 2021-04-21 to 2021-04-27
# Fetching news for 2021-04-28 to 2021-05-04
# Fetching news for 2021-05-05 to 2021-05-11
# Fetching news for 2021-05-12 to 2021-05-18
# Fetching news for 2021-05-19 to 2021-05-25
# Fetching news for 2021-05-26 to 2021-06-01
# Fetching news for 2021-06-02 to 2021-06-08
# Fetching news for 2021-06-09 to 2021-06-15
# Fetching news for 2021-06-16 to 2021-06-22
# Fetching news for 2021-06-23 to 2021-06-29
# Fetching news for 2021-06-30 to 2021-07-06
# Fetching news for 2021-07-07 to 2021-07-13
# Fetching news for 2021-07-14 to 2021-07-20
# Fetching news for 2021-07-21 to 2021-07-27
# Fetching news for 2021-07-28 to 2021-08-03
# Fetching news for 2021-08-04 to 2021-08-10
# Fetching news for 2021-08-11 to 2021-08-17
# Fetching news for 2021-08-18 to 2021-08-24
# Fetching news for 2021-08-25 to 2021-08-31
# Fetching news for 2021-09-01 to 2021-09-07
# Fetching news for 2021-09-08 to 2021-09-14
# Fetching news for 2021-09-15 to 2021-09-21
# Fetching news for 2021-09-22 to 2021-09-28
# Fetching news for 2021-09-29 to 2021-10-05
# Fetching news for 2021-10-06 to 2021-10-12
# Fetching news for 2021-10-13 to 2021-10-19
# Fetching news for 2021-10-20 to 2021-10-26
# Fetching news for 2021-10-27 to 2021-11-02
# Fetching news for 2021-11-03 to 2021-11-09
# Fetching news for 2021-11-10 to 2021-11-16
# Fetching news for 2021-11-17 to 2021-11-23
# Fetching news for 2021-11-24 to 2021-11-30
# Fetching news for 2021-12-01 to 2021-12-07
# Fetching news for 2021-12-08 to 2021-12-14
# Fetching news for 2021-12-15 to 2021-12-21
# Fetching news for 2021-12-22 to 2021-12-28
# Fetching news for 2021-12-29 to 2022-01-04
# Fetching news for 2022-01-05 to 2022-01-11
# Fetching news for 2022-01-12 to 2022-01-18
# Fetching news for 2022-01-19 to 2022-01-25
# Fetching news for 2022-01-26 to 2022-02-01
# Fetching news for 2022-02-02 to 2022-02-08
# Fetching news for 2022-02-09 to 2022-02-15
# Fetching news for 2022-02-16 to 2022-02-22
# Fetching news for 2022-02-23 to 2022-03-01
# Fetching news for 2022-03-02 to 2022-03-08
# Fetching news for 2022-03-09 to 2022-03-15
# Fetching news for 2022-03-16 to 2022-03-22
# Fetching news for 2022-03-23 to 2022-03-29
# Fetching news for 2022-03-30 to 2022-04-05
# Fetching news for 2022-04-06 to 2022-04-12
# Fetching news for 2022-04-13 to 2022-04-19
# Fetching news for 2022-04-20 to 2022-04-26
# Fetching news for 2022-04-27 to 2022-05-03
# Fetching news for 2022-05-04 to 2022-05-10
# Fetching news for 2022-05-11 to 2022-05-17
# Fetching news for 2022-05-18 to 2022-05-24
# Fetching news for 2022-05-25 to 2022-05-31
# Fetching news for 2022-06-01 to 2022-06-07
# Fetching news for 2022-06-08 to 2022-06-14
# Fetching news for 2022-06-15 to 2022-06-21
# Fetching news for 2022-06-22 to 2022-06-28
# Fetching news for 2022-06-29 to 2022-07-05
# Fetching news for 2022-07-06 to 2022-07-12
# Fetching news for 2022-07-13 to 2022-07-19
# Fetching news for 2022-07-20 to 2022-07-26
# Fetching news for 2022-07-27 to 2022-08-02
# Fetching news for 2022-08-03 to 2022-08-09
# Fetching news for 2022-08-10 to 2022-08-16
# Fetching news for 2022-08-17 to 2022-08-23
# Fetching news for 2022-08-24 to 2022-08-30
# Fetching news for 2022-08-31 to 2022-09-06
# Fetching news for 2022-09-07 to 2022-09-13
# Fetching news for 2022-09-14 to 2022-09-20
# Fetching news for 2022-09-21 to 2022-09-27
# Fetching news for 2022-09-28 to 2022-10-04
# Fetching news for 2022-10-05 to 2022-10-11
# Fetching news for 2022-10-12 to 2022-10-18
# Fetching news for 2022-10-19 to 2022-10-25
# Fetching news for 2022-10-26 to 2022-11-01
# Fetching news for 2022-11-02 to 2022-11-08
# Fetching news for 2022-11-09 to 2022-11-15
# Fetching news for 2022-11-16 to 2022-11-22
# Fetching news for 2022-11-23 to 2022-11-29
# Fetching news for 2022-11-30 to 2022-12-06
# Fetching news for 2022-12-07 to 2022-12-13
# Fetching news for 2022-12-14 to 2022-12-20
# Fetching news for 2022-12-21 to 2022-12-27
# Fetching news for 2022-12-28 to 2023-01-03
# Fetching news for 2023-01-04 to 2023-01-10
# Fetching news for 2023-01-11 to 2023-01-17
# Fetching news for 2023-01-18 to 2023-01-24
# Fetching news for 2023-01-25 to 2023-01-31
# Fetching news for 2023-02-01 to 2023-02-07
# Fetching news for 2023-02-08 to 2023-02-14
# Fetching news for 2023-02-15 to 2023-02-21
# Fetching news for 2023-02-22 to 2023-02-28
# Fetching news for 2023-03-01 to 2023-03-07
# Fetching news for 2023-03-08 to 2023-03-14
# Fetching news for 2023-03-15 to 2023-03-21
# Fetching news for 2023-03-22 to 2023-03-28
# Fetching news for 2023-03-29 to 2023-04-04
# Fetching news for 2023-04-05 to 2023-04-11
# Fetching news for 2023-04-12 to 2023-04-18
# Fetching news for 2023-04-19 to 2023-04-25
# Fetching news for 2023-04-26 to 2023-05-02
# Fetching news for 2023-05-03 to 2023-05-09
# Fetching news for 2023-05-10 to 2023-05-16
# Fetching news for 2023-05-17 to 2023-05-23
# Fetching news for 2023-05-24 to 2023-05-30
# Fetching news for 2023-05-31 to 2023-06-06
# Fetching news for 2023-06-07 to 2023-06-13
# Fetching news for 2023-06-14 to 2023-06-20
# Fetching news for 2023-06-21 to 2023-06-27
# Fetching news for 2023-06-28 to 2023-07-04
# Fetching news for 2023-07-05 to 2023-07-11
# Fetching news for 2023-07-12 to 2023-07-18
# Fetching news for 2023-07-19 to 2023-07-25
# Fetching news for 2023-07-26 to 2023-08-01
# Fetching news for 2023-08-02 to 2023-08-08
# Fetching news for 2023-08-09 to 2023-08-15
# Fetching news for 2023-08-16 to 2023-08-22
# Fetching news for 2023-08-23 to 2023-08-29
# Fetching news for 2023-08-30 to 2023-09-05
# Fetching news for 2023-09-06 to 2023-09-12
# Fetching news for 2023-09-13 to 2023-09-19
# Fetching news for 2023-09-20 to 2023-09-26
# Fetching news for 2023-09-27 to 2023-10-03
# Fetching news for 2023-10-04 to 2023-10-10
# Fetching news for 2023-10-11 to 2023-10-17
# Fetching news for 2023-10-18 to 2023-10-24
# Fetching news for 2023-10-25 to 2023-10-31
# Fetching news for 2023-11-01 to 2023-11-07
# Fetching news for 2023-11-08 to 2023-11-14
# Fetching news for 2023-11-15 to 2023-11-21
# Fetching news for 2023-11-22 to 2023-11-28
# Fetching news for 2023-11-29 to 2023-12-05
# Fetching news for 2023-12-06 to 2023-12-12
# Fetching news for 2023-12-13 to 2023-12-19
# Fetching news for 2023-12-20 to 2023-12-26
# Fetching news for 2023-12-27 to 2024-01-02
# Fetching news for 2024-01-03 to 2024-01-09
# Fetching news for 2024-01-10 to 2024-01-16
# Fetching news for 2024-01-17 to 2024-01-23
# Fetching news for 2024-01-24 to 2024-01-30
# Fetching news for 2024-01-31 to 2024-02-06
# Fetching news for 2024-02-07 to 2024-02-13
# Fetching news for 2024-02-14 to 2024-02-20
# Fetching news for 2024-02-21 to 2024-02-27
# Fetching news for 2024-02-28 to 2024-03-05
# Fetching news for 2024-03-06 to 2024-03-12
# Fetching news for 2024-03-13 to 2024-03-19
# Fetching news for 2024-03-20 to 2024-03-26
# Fetching news for 2024-03-27 to 2024-04-02
# Fetching news for 2024-04-03 to 2024-04-09
# Fetching news for 2024-04-10 to 2024-04-16
# Fetching news for 2024-04-17 to 2024-04-23
# Fetching news for 2024-04-24 to 2024-04-30
# Fetching news for 2024-05-01 to 2024-05-07
# Fetching news for 2024-05-08 to 2024-05-14
# Fetching news for 2024-05-15 to 2024-05-21
# Fetching news for 2024-05-22 to 2024-05-28
# Fetching news for 2024-05-29 to 2024-06-04
# Fetching news for 2024-06-05 to 2024-06-11
# Fetching news for 2024-06-12 to 2024-06-18
# Fetching news for 2024-06-19 to 2024-06-25
# Fetching news for 2024-06-26 to 2024-07-02
# Fetching news for 2024-07-03 to 2024-07-09
# Fetching news for 2024-07-10 to 2024-07-16
# Fetching news for 2024-07-17 to 2024-07-23
# Fetching news for 2024-07-24 to 2024-07-30
# Fetching news for 2024-07-31 to 2024-08-06
# Fetching news for 2024-08-07 to 2024-08-13
# Fetching news for 2024-08-14 to 2024-08-20
# Fetching news for 2024-08-21 to 2024-08-27
# Fetching news for 2024-08-28 to 2024-09-03
# Fetching news for 2024-09-04 to 2024-09-10
# Fetching news for 2024-09-11 to 2024-09-17
# Fetching news for 2024-09-18 to 2024-09-24
# Fetching news for 2024-09-25 to 2024-10-01
# Fetching news for 2024-10-02 to 2024-10-08
# Fetching news for 2024-10-09 to 2024-10-15
# Fetching news for 2024-10-16 to 2024-10-22
# Fetching news for 2024-10-23 to 2024-10-29
# Fetching news for 2024-10-30 to 2024-11-05
# Fetching news for 2024-11-06 to 2024-11-12
# Fetching news for 2024-11-13 to 2024-11-19
# Fetching news for 2024-11-20 to 2024-11-26
# Fetching news for 2024-11-27 to 2024-12-03
# Fetching news for 2024-12-04 to 2024-12-10
# Fetching news for 2024-12-11 to 2024-12-17
# Fetching news for 2024-12-18 to 2024-12-24
# Fetching news for 2024-12-25 to 2024-12-31
# Fetching news for 2025-01-01 to 2025-01-07
# Fetching news for 2025-01-08 to 2025-01-14
# Fetching news for 2025-01-15 to 2025-01-21
# Fetching news for 2025-01-22 to 2025-01-28
# Fetching news for 2025-01-29 to 2025-02-04
# Fetching news for 2025-02-05 to 2025-02-11
# Fetching news for 2025-02-12 to 2025-02-18
# Fetching news for 2025-02-19 to 2025-02-25
# Fetching news for 2025-02-26 to 2025-03-04
# Fetching news for 2025-03-05 to 2025-03-08
# All news data saved to NVDA_all_news_weekly.csv
